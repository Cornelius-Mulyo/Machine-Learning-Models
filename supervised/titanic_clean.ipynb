# %% [markdown]
# # Titanic ML Project
#
# Clean, structured implementation.

# %%
import pandas as pd

# Load dataset (update path)
# df = pd.read_csv('train.csv')

print('Load your Titanic dataset here')
